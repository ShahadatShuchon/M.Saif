# %%
import pandas as pd

# %% [markdown]
# # Columns Name in English

# %%
data_luzerne = pd.read_excel(r"C:\Users\Shahadat Shuchon\Documents\data luzerne\data_luzerne_evaluation.xls")
data_luzerne.head(2)
# Out:
#    Unnamed: 0  No ferme         Nom ferme   Responsable                Rue  \
# 0           1       136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1           2       136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipalité Province Code postal  Année  \
# 0      Mirabel   Québec      J7N2R8   2021
# 1      Mirabel   Québec      J7N2R8   2021
#
#                         ID unique champ  ...  Hauteur de tige 1 (cm)  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...                    17.0
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...                    20.0
#
#   Hauteur de tige 2 (cm)  Hauteur de tige 3 (cm) Hauteur de tige 4 (cm)  \
# 0                   20.0                    22.0                   24.0
# 1                   20.0                    26.0                   22.0
#
#   Hauteur de tige 5 (cm) Évaluation des racines  Longitude   Latitude  Borne  \
# 0                   27.0                    NaN -74.091891  45.547272    1.0
# 1                   22.0                    NaN -74.091917  45.547241    3.0
#
#                                   Photo
# 0  81a02657-8444-4e49-937d-6d944ee2387a
# 1  d2daa5e0-286f-4d0e-84c5-c916d028312e
#
# [2 rows x 27 columns]

# %%
data_luzerne.columns
# Out:
# Index(['Unnamed: 0', 'No ferme', 'Nom ferme', 'Responsable', 'Rue',
#        'Municipalité', 'Province', 'Code postal', 'Année', 'ID unique champ',
#        'No champ', 'Nom champ', 'No point', 'Nom point', 'État', 'Date',
#        'Nombre de tiges', 'Hauteur de tige 1 (cm)', 'Hauteur de tige 2 (cm)',
#        'Hauteur de tige 3 (cm)', 'Hauteur de tige 4 (cm)',
#        'Hauteur de tige 5 (cm)', 'Évaluation des racines', 'Longitude',
#        'Latitude', 'Borne', 'Photo'],
#       dtype='object')

# %%
data_luzerne = data_luzerne.rename({'No ferme':'JIRA_ID', 'Nom ferme':'Farm_Name', 'Responsable':'Producer','Rue':'Road', 'Municipalité':'Municipality', 'Code postal':'Postal_code','Année':'Year', 'ID unique champ':'Unique_ID', 'No champ':'Field_no','Nom champ':'Field_name', 'No point':'Point_no','Nom point':'Point_name', 'État':'Status', 'Nombre de tiges':'Stem_count','Hauteur de tige 1 (cm)':'Height_1cm', 'Hauteur de tige 2 (cm)':'Height_2cm','Hauteur de tige 3 (cm)':'Height_3cm', 'Hauteur de tige 4 (cm)':'Height_4cm', 'Hauteur de tige 5 (cm)':'Height_5cm','Borne':'Land_mark'}, axis='columns')
data_luzerne.head(2)
# Out:
#    Unnamed: 0  JIRA_ID         Farm_Name      Producer               Road  \
# 0           1      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1           2      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province Postal_code  Year  \
# 0      Mirabel   Québec      J7N2R8  2021
# 1      Mirabel   Québec      J7N2R8  2021
#
#                               Unique_ID  ...  Height_1cm Height_2cm  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        17.0       20.0
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        20.0       20.0
#
#    Height_3cm Height_4cm Height_5cm Évaluation des racines  Longitude  \
# 0        22.0       24.0       27.0                    NaN -74.091891
# 1        26.0       22.0       22.0                    NaN -74.091917
#
#     Latitude  Land_mark                                 Photo
# 0  45.547272        1.0  81a02657-8444-4e49-937d-6d944ee2387a
# 1  45.547241        3.0  d2daa5e0-286f-4d0e-84c5-c916d028312e
#
# [2 rows x 27 columns]

# %% [markdown]
# # adding Adviser

# %%
id_unique = pd.read_excel(r"C:\Users\Shahadat Shuchon\Documents\data luzerne\ID_unique.xlsx")
id_unique.head(2)
# Out:
#    Society_no                             Society_name Field_name  Field_no  \
# 0       37034                              Hurni, Andr          3  84356113
# 1       37034  Hurni, AndrLas (Ferme Techno-Lait SENC)         33  84356112
#
#                               Unique_ID CULTURE                  User  \
# 0  3c88a96e-45cd-41a9-979f-c739f8b9e054     NaN  Elizabeth  L'Heureux
# 1  71378500-5572-449c-a541-fcd4dfba90e1     NaN  Elizabeth  L'Heureux
#
#                    Farm_name       Producer              Adviser  JIRA_ID  \
# 0  Ferme Techno-Lait S.EN.C.  Andréas Hurni  Elisabeth L'Heureux        0
# 1  Ferme Techno-Lait S.EN.C.  Andréas Hurni  Elisabeth L'Heureux        0
#
#    Longitude   Latitude
# 0 -72.612200  45.747451
# 1 -72.597395  45.763746

# %%
id_unique =id_unique[['Unique_ID','Adviser']]

# %%
data_luzerne_rev = pd.merge(data_luzerne, id_unique, on="Unique_ID", how='left')
data_luzerne_rev.head(2)
# Out:
#    Unnamed: 0  JIRA_ID         Farm_Name      Producer               Road  \
# 0           1      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1           2      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province Postal_code  Year  \
# 0      Mirabel   Québec      J7N2R8  2021
# 1      Mirabel   Québec      J7N2R8  2021
#
#                               Unique_ID  ...  Height_2cm Height_3cm  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        20.0       22.0
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        20.0       26.0
#
#    Height_4cm Height_5cm Évaluation des racines  Longitude   Latitude  \
# 0        24.0       27.0                    NaN -74.091891  45.547272
# 1        22.0       22.0                    NaN -74.091917  45.547241
#
#    Land_mark                                 Photo     Adviser
# 0        1.0  81a02657-8444-4e49-937d-6d944ee2387a  Evens Jean
# 1        3.0  d2daa5e0-286f-4d0e-84c5-c916d028312e  Evens Jean
#
# [2 rows x 28 columns]

# %% [markdown]
# # Month Extraction

# %%
data_luzerne_rev['Month'] = data_luzerne_rev['Date'].dt.month
data_luzerne_rev['Month'] = data_luzerne_rev['Date'].dt.strftime('%B')
data_luzerne_rev.head(2)
# Out:
#    Unnamed: 0  JIRA_ID         Farm_Name      Producer               Road  \
# 0           1      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1           2      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province Postal_code  Year  \
# 0      Mirabel   Québec      J7N2R8  2021
# 1      Mirabel   Québec      J7N2R8  2021
#
#                               Unique_ID  ...  Height_3cm Height_4cm  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        22.0       24.0
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        26.0       22.0
#
#    Height_5cm Évaluation des racines  Longitude   Latitude  Land_mark  \
# 0        27.0                    NaN -74.091891  45.547272        1.0
# 1        22.0                    NaN -74.091917  45.547241        3.0
#
#                                   Photo     Adviser      Month
# 0  81a02657-8444-4e49-937d-6d944ee2387a  Evens Jean  September
# 1  d2daa5e0-286f-4d0e-84c5-c916d028312e  Evens Jean  September
#
# [2 rows x 29 columns]

# %% [markdown]
# # season inclution

# %%
def label_race (row):
   if row['Month'] == 'May' :
      return 'Spring'
   if row['Month'] == 'June' :
      return 'Spring'
   if row['Month'] == 'July' :
      return 'Spring'
   if row['Month'] == 'August':
      return 'Fall'
   if row['Month']  == 'September':
      return 'Fall'
   if row['Month'] == 'October':
      return 'Fall'
   if row['Month'] == 'November':
      return 'Fall'
   if row['Month'] == 'December':
      return 'Fall'

# %%
data_luzerne_rev['Season'] = data_luzerne_rev.apply (lambda row: label_race(row), axis=1)
data_luzerne_rev.head(2)
# Out:
#    Unnamed: 0  JIRA_ID         Farm_Name      Producer               Road  \
# 0           1      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1           2      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province Postal_code  Year  \
# 0      Mirabel   Québec      J7N2R8  2021
# 1      Mirabel   Québec      J7N2R8  2021
#
#                               Unique_ID  ...  Height_4cm Height_5cm  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        24.0       27.0
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        22.0       22.0
#
#    Évaluation des racines  Longitude   Latitude Land_mark  \
# 0                     NaN -74.091891  45.547272       1.0
# 1                     NaN -74.091917  45.547241       3.0
#
#                                   Photo     Adviser      Month  Season
# 0  81a02657-8444-4e49-937d-6d944ee2387a  Evens Jean  September    Fall
# 1  d2daa5e0-286f-4d0e-84c5-c916d028312e  Evens Jean  September    Fall
#
# [2 rows x 30 columns]

# %% [markdown]
# # Filtering nan rows

# %%
data_luzerne_rev = data_luzerne_rev[data_luzerne_rev[['Point_no', 'Stem_count', 'Height_1cm','Height_2cm','Height_3cm','Height_4cm','Height_5cm','Longitude','Latitude']].notnull().all(1)]
data_luzerne_rev.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SHAHAD~1\AppData\Local\Temp/ipykernel_9656/42413380.py in <module>
# ----> 1 data_luzerne_rev = data_luzerne_rev[data_luzerne_rev[['Point_no', 'Stem_count', 'Height_1cm','Height_2cm','Height_3cm','Height_4cm','Height_5cm','Longitude','Latitude']].notnull().all(1)]
#       2 data_luzerne_rev.head(2)
#
# NameError: name 'data_luzerne_rev' is not defined

# %%
data_luzerne_rev.to_excel("data_luzerne_rev.xlsx")

# %%
data_luzerne_rev.Province.unique()
# Out:
# array(['Québec', nan, 'Ontario', 'Nouvelle-Écosse', 'Manitoba'],
#       dtype=object)
