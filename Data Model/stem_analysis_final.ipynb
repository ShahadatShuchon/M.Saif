# %% [markdown]
# # Data Formation

# %%
import pandas as pd

# %% [markdown]
# # stem count raw and id unique join

# %%
id_unique_rev = pd.read_excel(r'C:\Users\Shahadat Shuchon\Documents\M.Saif\Data Model\Data_model_100222.xlsx', sheet_name ='ID_unique_revised')
#id_unique_rev.head()

# %%
stem_raw = pd.read_excel(r'C:\Users\Shahadat Shuchon\Documents\M.Saif\Data Model\Data_model_100222.xlsx', sheet_name ='Stem_count_raw')
#stem_raw.head()

# %%
stem_id_unique = pd.merge(stem_raw, id_unique_rev, on="Unique_ID", how='left')
#stem_id_unique.head()

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# # Month Extraction

# %%
stem_id_unique['Month'] = stem_id_unique['Date'].dt.month
stem_id_unique['Month'] = stem_id_unique['Date'].dt.strftime('%B')
#stem_id_unique_n.head()
#df['Month']

# %% [markdown]
# # season inclution

# %% [markdown]
# # Dataframe

# %%
df = pd.read_excel(r'C:\Users\Shahadat Shuchon\Documents\M.Saif\Data Model\Data_model_100222.xlsx', sheet_name ='Stem_count_id')
df.head()
# Out:
#    Unnamed: 0  Column1  JIRA_ID         Farm_Name      Producer  \
# 0           0        1      136  Ferme Pioui SENC  Pascal Leduc
# 1           1        2      136  Ferme Pioui SENC  Pascal Leduc
# 2           2        3      136  Ferme Pioui SENC  Pascal Leduc
# 3           3        4      136  Ferme Pioui SENC  Pascal Leduc
# 4           4        5      136  Ferme Pioui SENC  Pascal Leduc
#
#                 Road Municipality Province Postal_code  Year  ...   Latitude  \
# 0  8821 rg Fresniere      Mirabel   Québec      J7N2R8  2021  ...  45.547272
# 1  8821 rg Fresniere      Mirabel   Québec      J7N2R8  2021  ...  45.547241
# 2  8821 rg Fresniere      Mirabel   Québec      J7N2R8  2021  ...  45.546173
# 3  8821 rg Fresniere      Mirabel   Québec      J7N2R8  2021  ...  45.546173
# 4  8821 rg Fresniere      Mirabel   Québec      J7N2R8  2021  ...  45.547272
#
#    Land_mark                                 Photo  Society_no  \
# 0        1.0  81a02657-8444-4e49-937d-6d944ee2387a     36832.0
# 1        3.0  d2daa5e0-286f-4d0e-84c5-c916d028312e     36832.0
# 2        1.0  60350fb2-9e5e-4201-a75f-6a0bb2238efb     36832.0
# 3        3.0  85db76b9-8814-40c4-bdee-6b5bf45660a9     36832.0
# 4        2.0  7b77ea66-fce2-4829-90ca-d1790ca5d171     36832.0
#
#                                  Society_name    Field_no             CULTURE  \
# 0  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0  Foin 1tablissement
# 1  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0  Foin 1tablissement
# 2  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0  Foin 1tablissement
# 3  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0  Foin 1tablissement
# 4  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0  Foin 1tablissement
#
#      User     Adviser  Season
# 0  Logiag  Evens Jean    Fall
# 1  Logiag  Evens Jean    Fall
# 2  Logiag  Evens Jean    Fall
# 3  Logiag  Evens Jean    Fall
# 4  Logiag  Evens Jean    Fall
#
# [5 rows x 36 columns]

# %%
#df.Month.unique()

# %% [raw]
# def label_race (row):
#    if row['Month'] == 'May' :
#       return 'Spring'
#    if row['Month'] == 'June' :
#       return 'Spring'
#    if row['Month'] == 'July' :
#       return 'Spring'
#    if row['Month'] == 'August':
#       return 'Fall'
#    if row['Month']  == 'September':
#       return 'Fall'
#    if row['Month'] == 'October':
#       return 'Fall'
#    if row['Month'] == 'November':
#       return 'Fall'
#    if row['Month'] == 'December':
#       return 'Fall'

# %%
#df['Season'] = df.apply (lambda row: label_race(row), axis=1)
#df.head()

# %%
#df.to_excel('stem_id_unique.xlsx')

# %%
#df = df[['Farm_name', 'Date']]
#df.head()

# %%
#import datetime

#df['Month'] = datetime.date.df['Month'].strftime('%B')

#df['Month']

# %%
#list(df.columns)

# %%
#df.JIRA_ID.unique()

# %%
#df.No_champ.unique()

# %% [markdown]
# # Data Processing

# %% [markdown]
# # Farm Name/ JIRA Id Table

# %%
df1=df[['JIRA_ID','Farm_Name','Producer','Adviser']]
df1.head()
# Out:
#    JIRA_ID         Farm_Name      Producer     Adviser
# 0      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 1      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 2      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 3      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 4      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean

# %%
df2 = df1.drop_duplicates(subset=['JIRA_ID'], keep='last')

df2=pd.DataFrame(df2)
df2.head()
#un = df1.nunique()
#un
# Out:
#      JIRA_ID                      Farm_Name              Producer     Adviser
# 50       136               Ferme Pioui SENC          Pascal Leduc  Evens Jean
# 110      137             Ferme Dexpro SENC.     Sébastien  Proulx  Evens Jean
# 156      138            Ferme Modo S.E.N.C.            Guy Mondou  Evens Jean
# 228      139   Ferme Laitière Ambijoie inc.        Martin Gratton  Evens Jean
# 282      140  Ferme C. & F. Fankhauser Inc.  Christian Fankhauser  Evens Jean

# %%
data1=df[["JIRA_ID", "Stem_count"]].groupby("JIRA_ID").describe()
data1=pd.DataFrame(data1)
data1#.head()
# Out:
#         Stem_count
#              count       mean        std   min    25%   50%    75%    max
# JIRA_ID
# 136           51.0  30.196078  21.590757   1.0  11.00  29.0  45.50   90.0
# 137           60.0  42.566667  28.943760   0.0  19.75  38.5  54.25  126.0
# 138           46.0  48.239130  24.073208   3.0  32.25  51.5  66.50   96.0
# 139           72.0  54.236111  19.857587  21.0  38.75  52.0  67.75  111.0
# 140           54.0  28.462963  16.487517   5.0  15.25  26.0  42.00   79.0
# ...            ...        ...        ...   ...    ...   ...    ...    ...
# 449           15.0  56.266667  16.524729  32.0  44.50  56.0  66.00   97.0
# 452            0.0        NaN        NaN   NaN    NaN   NaN    NaN    NaN
# 453            0.0        NaN        NaN   NaN    NaN   NaN    NaN    NaN
# 454            0.0        NaN        NaN   NaN    NaN   NaN    NaN    NaN
# 455            0.0        NaN        NaN   NaN    NaN   NaN    NaN    NaN
#
# [249 rows x 8 columns]

# %%
data1.to_excel("stem_analysis_JIRA_ID_stem_count_descriptive_statistics.xlsx")

# %%
#data2=df[['JIRA_ID','Farm_name','Adviser']].unique("JIRA_ID")
#data2.head()
df3 = pd.merge(df2, data1, how="right", on="JIRA_ID")
df3.head()
# Out:
# C:\Users\SHAHAD~1\AppData\Local\Temp/ipykernel_9788/863424386.py:3: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   df3 = pd.merge(df2, data1, how="right", on="JIRA_ID")
#    JIRA_ID                      Farm_Name              Producer     Adviser  \
# 0      136               Ferme Pioui SENC          Pascal Leduc  Evens Jean
# 1      137             Ferme Dexpro SENC.     Sébastien  Proulx  Evens Jean
# 2      138            Ferme Modo S.E.N.C.            Guy Mondou  Evens Jean
# 3      139   Ferme Laitière Ambijoie inc.        Martin Gratton  Evens Jean
# 4      140  Ferme C. & F. Fankhauser Inc.  Christian Fankhauser  Evens Jean
#
#    (Stem_count, count)  (Stem_count, mean)  (Stem_count, std)  \
# 0                 51.0           30.196078          21.590757
# 1                 60.0           42.566667          28.943760
# 2                 46.0           48.239130          24.073208
# 3                 72.0           54.236111          19.857587
# 4                 54.0           28.462963          16.487517
#
#    (Stem_count, min)  (Stem_count, 25%)  (Stem_count, 50%)  (Stem_count, 75%)  \
# 0                1.0              11.00               29.0              45.50
# 1                0.0              19.75               38.5              54.25
# 2                3.0              32.25               51.5              66.50
# 3               21.0              38.75               52.0              67.75
# 4                5.0              15.25               26.0              42.00
#
#    (Stem_count, max)
# 0               90.0
# 1              126.0
# 2               96.0
# 3              111.0
# 4               79.0

# %%
#df3 = pd.merge(df1,data1,how="right", on="JIRA_ID")
#df3.head()

# %%
df3.to_excel("stem_analysis_JIRA_ID_descriptive_analysis_farm_name_adviser.xlsx")

# %% [markdown]
# # No champ/ Field name Table

# %%
data2= df[["Field_name", "Stem_count"]].groupby("Field_name").describe()
data2=pd.DataFrame(data2)
data2
# Out:
#                   Stem_count                                                  \
#                        count       mean        std   min    25%   50%    75%
# Field_name
# 001                      0.0        NaN        NaN   NaN    NaN   NaN    NaN
# 005                     24.0  66.875000  13.702785  33.0  60.00  68.5  76.00
# 009                     24.0  74.958333  16.313449  46.0  61.25  75.0  88.25
# 01                      18.0  49.333333  13.033892  28.0  41.25  49.0  54.00
# 015                      0.0        NaN        NaN   NaN    NaN   NaN    NaN
# ...                      ...        ...        ...   ...    ...   ...    ...
# Zenda Dairy farms       30.0  58.333333  11.609548  29.0  54.00  57.0  63.00
# p4                       0.0        NaN        NaN   NaN    NaN   NaN    NaN
# ph3                     12.0  37.250000  16.421300   9.0  25.75  42.5  51.00
# ph4                      6.0  34.333333  12.564500  18.0  24.50  36.5  42.50
# ph5                      6.0  45.333333   9.729680  26.0  46.00  49.5  50.75
#
#
#                      max
# Field_name
# 001                  NaN
# 005                 86.0
# 009                101.0
# 01                  87.0
# 015                  NaN
# ...                  ...
# Zenda Dairy farms   87.0
# p4                   NaN
# ph3                 57.0
# ph4                 50.0
# ph5                 51.0
#
# [403 rows x 8 columns]

# %%
data2.to_excel("stem_analysis_No_champ_stem_count_descriptive_statistics.xlsx")

# %%
df4=df[['Field_name','Farm_Name','Producer','Adviser']]
df4.head()
# Out:
#   Field_name         Farm_Name      Producer     Adviser
# 0         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 1         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 2         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 3         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 4         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean

# %%
df5 = df4.drop_duplicates(subset=['Field_name'], keep='last')

df5=pd.DataFrame(df5)
df5.head()
# Out:
#     Field_name           Farm_Name           Producer     Adviser
# 9           68    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 20          70    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 32          71    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 92       25-26  Ferme Dexpro SENC.  Sébastien  Proulx  Evens Jean
# 110      6A+6B  Ferme Dexpro SENC.  Sébastien  Proulx  Evens Jean

# %%
df6 = pd.merge(df5, data2, how="right", on="Field_name")
df6.head()
# Out:
# C:\Users\SHAHAD~1\AppData\Local\Temp/ipykernel_9788/2591909051.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   df6 = pd.merge(df5, data2, how="right", on="Field_name")
#   Field_name                         Farm_Name            Producer  \
# 0        001         Ferme M.Grenier& fils inc      Grenier, Anita
# 1        005       Ferme Rodrigue et fils inc.    Rodrigue, Réjean
# 2        009       Ferme Rodrigue et fils inc.    Rodrigue, Réjean
# 3         01  Ferme D.N. Vallières (2005) inc.  Vallières, Dominic
# 4        015         Ferme M.Grenier& fils inc      Grenier, Anita
#
#               Adviser  (Stem_count, count)  (Stem_count, mean)  \
# 0  Krystal Coddington                  0.0                 NaN
# 1     Nancie Belanger                 24.0           66.875000
# 2     Nancie Belanger                 24.0           74.958333
# 3     Dominique Fiset                 18.0           49.333333
# 4  Krystal Coddington                  0.0                 NaN
#
#    (Stem_count, std)  (Stem_count, min)  (Stem_count, 25%)  (Stem_count, 50%)  \
# 0                NaN                NaN                NaN                NaN
# 1          13.702785               33.0              60.00               68.5
# 2          16.313449               46.0              61.25               75.0
# 3          13.033892               28.0              41.25               49.0
# 4                NaN                NaN                NaN                NaN
#
#    (Stem_count, 75%)  (Stem_count, max)
# 0                NaN                NaN
# 1              76.00               86.0
# 2              88.25              101.0
# 3              54.00               87.0
# 4                NaN                NaN

# %%
df6.to_excel("stem_analysis_Field_name_descriptive_statistics_farm_name_adviser.xlsx")

# %% [markdown]
# # JIRA ID / Farm Name Seasons Table

# %% [markdown]
# # Fall

# %%
dff = df[df['Season']=='Fall']
dff=dff[['JIRA_ID','Farm_Name','Producer','Adviser']]
dff.head()
# Out:
#    JIRA_ID         Farm_Name      Producer     Adviser
# 0      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 1      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 2      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 3      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 4      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean

# %%
dff = dff.drop_duplicates(subset=['JIRA_ID'], keep='last')

dff=pd.DataFrame(dff)
dff.head()
# Out:
#      JIRA_ID                      Farm_Name              Producer     Adviser
# 47       136               Ferme Pioui SENC          Pascal Leduc  Evens Jean
# 109      137             Ferme Dexpro SENC.     Sébastien  Proulx  Evens Jean
# 149      138            Ferme Modo S.E.N.C.            Guy Mondou  Evens Jean
# 228      139   Ferme Laitière Ambijoie inc.        Martin Gratton  Evens Jean
# 282      140  Ferme C. & F. Fankhauser Inc.  Christian Fankhauser  Evens Jean

# %%
dff1=df[["JIRA_ID", "Stem_count"]].groupby("JIRA_ID").describe()
dff1=pd.DataFrame(dff1)
dff1.head()
# Out:
#         Stem_count
#              count       mean        std   min    25%   50%    75%    max
# JIRA_ID
# 136           51.0  30.196078  21.590757   1.0  11.00  29.0  45.50   90.0
# 137           60.0  42.566667  28.943760   0.0  19.75  38.5  54.25  126.0
# 138           46.0  48.239130  24.073208   3.0  32.25  51.5  66.50   96.0
# 139           72.0  54.236111  19.857587  21.0  38.75  52.0  67.75  111.0
# 140           54.0  28.462963  16.487517   5.0  15.25  26.0  42.00   79.0

# %%
dff2 = pd.merge(dff, dff1, how="left", on="JIRA_ID")
dff2.head()
# Out:
# C:\Users\SHAHAD~1\AppData\Local\Temp/ipykernel_9788/557476607.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   dff2 = pd.merge(dff, dff1, how="left", on="JIRA_ID")
#    JIRA_ID                      Farm_Name              Producer     Adviser  \
# 0      136               Ferme Pioui SENC          Pascal Leduc  Evens Jean
# 1      137             Ferme Dexpro SENC.     Sébastien  Proulx  Evens Jean
# 2      138            Ferme Modo S.E.N.C.            Guy Mondou  Evens Jean
# 3      139   Ferme Laitière Ambijoie inc.        Martin Gratton  Evens Jean
# 4      140  Ferme C. & F. Fankhauser Inc.  Christian Fankhauser  Evens Jean
#
#    (Stem_count, count)  (Stem_count, mean)  (Stem_count, std)  \
# 0                 51.0           30.196078          21.590757
# 1                 60.0           42.566667          28.943760
# 2                 46.0           48.239130          24.073208
# 3                 72.0           54.236111          19.857587
# 4                 54.0           28.462963          16.487517
#
#    (Stem_count, min)  (Stem_count, 25%)  (Stem_count, 50%)  (Stem_count, 75%)  \
# 0                1.0              11.00               29.0              45.50
# 1                0.0              19.75               38.5              54.25
# 2                3.0              32.25               51.5              66.50
# 3               21.0              38.75               52.0              67.75
# 4                5.0              15.25               26.0              42.00
#
#    (Stem_count, max)
# 0               90.0
# 1              126.0
# 2               96.0
# 3              111.0
# 4               79.0

# %%
dff2.to_excel("stem_analysis_JIRA_ID_Fall_season_descriptive_analysis.xlsx")

# %% [markdown]
# # Spring

# %%
dfs = df[df['Season']=='Spring']
dfs=dfs[['JIRA_ID','Farm_Name','Producer','Adviser']]
dfs.head()
# Out:
#     JIRA_ID         Farm_Name      Producer     Adviser
# 9       136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 10      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 14      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 15      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 16      136  Ferme Pioui SENC  Pascal Leduc  Evens Jean

# %%
dfsc = dfs.drop_duplicates(subset=['JIRA_ID'], keep='last')

dfsc=pd.DataFrame(dfsc)
dfsc.head()
# Out:
#      JIRA_ID                      Farm_Name              Producer     Adviser
# 50       136               Ferme Pioui SENC          Pascal Leduc  Evens Jean
# 110      137             Ferme Dexpro SENC.     Sébastien  Proulx  Evens Jean
# 156      138            Ferme Modo S.E.N.C.            Guy Mondou  Evens Jean
# 225      139   Ferme Laitière Ambijoie inc.        Martin Gratton  Evens Jean
# 279      140  Ferme C. & F. Fankhauser Inc.  Christian Fankhauser  Evens Jean

# %%
dfs1=df[["JIRA_ID", "Stem_count"]].groupby("JIRA_ID").describe()
dfs1=pd.DataFrame(dfs1)
dfs1.head()
# Out:
#         Stem_count
#              count       mean        std   min    25%   50%    75%    max
# JIRA_ID
# 136           51.0  30.196078  21.590757   1.0  11.00  29.0  45.50   90.0
# 137           60.0  42.566667  28.943760   0.0  19.75  38.5  54.25  126.0
# 138           46.0  48.239130  24.073208   3.0  32.25  51.5  66.50   96.0
# 139           72.0  54.236111  19.857587  21.0  38.75  52.0  67.75  111.0
# 140           54.0  28.462963  16.487517   5.0  15.25  26.0  42.00   79.0

# %%
dfs2 = pd.merge(dfsc, dfs1, how="left", on="JIRA_ID")
dfs2.head()
# Out:
# C:\Users\SHAHAD~1\AppData\Local\Temp/ipykernel_9788/2550695234.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   dfs2 = pd.merge(dfsc, dfs1, how="left", on="JIRA_ID")
#    JIRA_ID                      Farm_Name              Producer     Adviser  \
# 0      136               Ferme Pioui SENC          Pascal Leduc  Evens Jean
# 1      137             Ferme Dexpro SENC.     Sébastien  Proulx  Evens Jean
# 2      138            Ferme Modo S.E.N.C.            Guy Mondou  Evens Jean
# 3      139   Ferme Laitière Ambijoie inc.        Martin Gratton  Evens Jean
# 4      140  Ferme C. & F. Fankhauser Inc.  Christian Fankhauser  Evens Jean
#
#    (Stem_count, count)  (Stem_count, mean)  (Stem_count, std)  \
# 0                 51.0           30.196078          21.590757
# 1                 60.0           42.566667          28.943760
# 2                 46.0           48.239130          24.073208
# 3                 72.0           54.236111          19.857587
# 4                 54.0           28.462963          16.487517
#
#    (Stem_count, min)  (Stem_count, 25%)  (Stem_count, 50%)  (Stem_count, 75%)  \
# 0                1.0              11.00               29.0              45.50
# 1                0.0              19.75               38.5              54.25
# 2                3.0              32.25               51.5              66.50
# 3               21.0              38.75               52.0              67.75
# 4                5.0              15.25               26.0              42.00
#
#    (Stem_count, max)
# 0               90.0
# 1              126.0
# 2               96.0
# 3              111.0
# 4               79.0

# %%
dfs2.to_excel("stem_analysis_JIRA_ID_Spring_season_descriptive_analysis.xlsx")

# %% [markdown]
# # No champ / Field Name Season Table

# %% [markdown]
# # Fall

# %%
df_f = df[df['Season']=='Fall']
df_f=df_f[['Field_name','Farm_Name','Producer','Adviser']]
df_f.head()
# Out:
#   Field_name         Farm_Name      Producer     Adviser
# 0         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 1         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 2         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 3         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 4         51  Ferme Pioui SENC  Pascal Leduc  Evens Jean

# %%
df_f = df_f.drop_duplicates(subset=['Field_name'], keep='last')

df_f=pd.DataFrame(df_f)
df_f.head()
# Out:
#    Field_name           Farm_Name           Producer     Adviser
# 8          68    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 20         70    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 32         71    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 47         78    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 91      25-26  Ferme Dexpro SENC.  Sébastien  Proulx  Evens Jean

# %%
df_1=df[["Field_name", "Stem_count"]].groupby("Field_name").describe()
df_1=pd.DataFrame(df_1)
df_1.head()
# Out:
#            Stem_count
#                 count       mean        std   min    25%   50%    75%    max
# Field_name
# 001               0.0        NaN        NaN   NaN    NaN   NaN    NaN    NaN
# 005              24.0  66.875000  13.702785  33.0  60.00  68.5  76.00   86.0
# 009              24.0  74.958333  16.313449  46.0  61.25  75.0  88.25  101.0
# 01               18.0  49.333333  13.033892  28.0  41.25  49.0  54.00   87.0
# 015               0.0        NaN        NaN   NaN    NaN   NaN    NaN    NaN

# %%
df_2 = pd.merge(df_f, df_1, how="left", on="Field_name")
df_2#.head()
# Out:
# C:\Users\SHAHAD~1\AppData\Local\Temp/ipykernel_9788/3649680440.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   df_2 = pd.merge(df_f, df_1, how="left", on="Field_name")
#     Field_name                              Farm_Name            Producer  \
# 0           68                       Ferme Pioui SENC        Pascal Leduc
# 1           70                       Ferme Pioui SENC        Pascal Leduc
# 2           71                       Ferme Pioui SENC        Pascal Leduc
# 3           78                       Ferme Pioui SENC        Pascal Leduc
# 4        25-26                     Ferme Dexpro SENC.   Sébastien  Proulx
# ..         ...                                    ...                 ...
# 215         33               Ferme Beauvilait S.E.N.C  Beaucage, Stéphane
# 216          3     Urbain, Normand (Ferme Gilnor enr)                 NaN
# 217          4     Urbain, Normand (Ferme Gilnor enr)                 NaN
# 218          8     Urbain, Normand (Ferme Gilnor enr)                 NaN
# 219         22  Ferme Michel et Céline Chevrette enr.   Chevrette, Michel
#
#           Adviser  (Stem_count, count)  (Stem_count, mean)  (Stem_count, std)  \
# 0      Evens Jean                  4.0           22.500000          13.964240
# 1      Evens Jean                  5.0           19.400000          16.831518
# 2      Evens Jean                 12.0           40.000000          21.127320
# 3      Evens Jean                 18.0           28.500000          22.778344
# 4      Evens Jean                 24.0           33.791667          21.863170
# ..            ...                  ...                 ...                ...
# 215  Imed Hasni\t                 39.0           42.589744          16.881503
# 216           NaN                185.0           55.286486          28.293667
# 217           NaN                186.0           49.838710          25.703839
# 218           NaN                186.0           46.865591          23.278994
# 219           NaN                187.0           54.705882          27.067501
#
#      (Stem_count, min)  (Stem_count, 25%)  (Stem_count, 50%)  \
# 0                  3.0              18.75               25.5
# 1                  1.0               1.00               30.0
# 2                  8.0              21.50               44.5
# 3                  5.0              11.00               20.5
# 4                  0.0              15.75               26.5
# ..                 ...                ...                ...
# 215               15.0              31.00               40.0
# 216                3.0              36.00               53.0
# 217                5.0              31.00               46.0
# 218                0.0              29.25               48.0
# 219                4.0              37.00               49.0
#
#      (Stem_count, 75%)  (Stem_count, max)
# 0                29.25               36.0
# 1                32.00               33.0
# 2                52.50               73.0
# 3                43.25               90.0
# 4                49.00               77.0
# ..                 ...                ...
# 215              48.50               92.0
# 216              74.00              160.0
# 217              66.00              129.0
# 218              61.00              118.0
# 219              69.50              188.0
#
# [220 rows x 12 columns]

# %%
df_2.to_excel("stem_analysis_Field_name_Fall_season_descriptive_analysis.xlsx")

# %% [markdown]
# # Spring

# %%
df_s = df[df['Season']=='Spring']
df_s=df_s[['Field_name','Farm_Name','Producer','Adviser']]
df_s.head()
# Out:
#    Field_name         Farm_Name      Producer     Adviser
# 9          68  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 10          7  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 14          7  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 15          7  Ferme Pioui SENC  Pascal Leduc  Evens Jean
# 16         70  Ferme Pioui SENC  Pascal Leduc  Evens Jean

# %%
df_s = df_s.drop_duplicates(subset=['Field_name'], keep='last')
df_s=pd.DataFrame(df_s)
df_s.head()
# Out:
#    Field_name           Farm_Name           Producer     Adviser
# 9          68    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 17         70    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 31         71    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 50         78    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 92      25-26  Ferme Dexpro SENC.  Sébastien  Proulx  Evens Jean

# %%
df_3 = pd.merge(df_s, df_1, how="left", on="Field_name")
df_3.head()
# Out:
# C:\Users\SHAHAD~1\AppData\Local\Temp/ipykernel_9788/1598183417.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   df_3 = pd.merge(df_s, df_1, how="left", on="Field_name")
#   Field_name           Farm_Name           Producer     Adviser  \
# 0         68    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 1         70    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 2         71    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 3         78    Ferme Pioui SENC       Pascal Leduc  Evens Jean
# 4      25-26  Ferme Dexpro SENC.  Sébastien  Proulx  Evens Jean
#
#    (Stem_count, count)  (Stem_count, mean)  (Stem_count, std)  \
# 0                  4.0           22.500000          13.964240
# 1                  5.0           19.400000          16.831518
# 2                 12.0           40.000000          21.127320
# 3                 18.0           28.500000          22.778344
# 4                 24.0           33.791667          21.863170
#
#    (Stem_count, min)  (Stem_count, 25%)  (Stem_count, 50%)  (Stem_count, 75%)  \
# 0                3.0              18.75               25.5              29.25
# 1                1.0               1.00               30.0              32.00
# 2                8.0              21.50               44.5              52.50
# 3                5.0              11.00               20.5              43.25
# 4                0.0              15.75               26.5              49.00
#
#    (Stem_count, max)
# 0               36.0
# 1               33.0
# 2               73.0
# 3               90.0
# 4               77.0

# %%
df_3.to_excel("stem_analysis_Field_name_Spring_season_descriptive_analysis.xlsx")

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # JIRA_ID Histogram

# %%
df['JIRA_ID'].plot(kind='hist',bins=20,color = "steelblue", rwidth=0.95)
#plt.title('Spring')
plt.xlabel('JIRA ID')
plt.ylabel('No. of obsevation')

fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('JIRA_ID_Histogram.jpg', dpi= 500)

# %%
df.Season.unique()
# Out:
# array(['Fall', 'Spring', nan], dtype=object)

# %%
fd = df[["Province","Season", "Stem_count"]]
fd = fd[fd['Stem_count']<=150]
fd.head()
# Out:
#   Province Season  Stem_count
# 0   Québec   Fall        17.0
# 1   Québec   Fall        10.0
# 2   Québec   Fall         5.0
# 3   Québec   Fall         4.0
# 4   Québec   Fall        45.0

# %%
a=fd.loc[(fd['Season']== 'Spring')]
a.head()
# Out:
#    Province  Season  Stem_count
# 9    Québec  Spring         3.0
# 10   Québec  Spring        47.0
# 14   Québec  Spring        36.0
# 15   Québec  Spring        28.0
# 16   Québec  Spring         1.0

# %%
a['Stem_count'].plot(kind='hist',color = "skyblue", rwidth=0.95)
plt.title('Spring')
plt.xlabel('Stem count')
plt.ylabel('No. of obsevation')
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
#plt.axvspan(x, y, color='w', alpha=0.5, lw=0)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('season_spring_stem_count.jpg', dpi= 500)

# %%
b=fd.loc[(fd['Season']== 'Fall')]
b.head()
# Out:
#   Province Season  Stem_count
# 0   Québec   Fall        17.0
# 1   Québec   Fall        10.0
# 2   Québec   Fall         5.0
# 3   Québec   Fall         4.0
# 4   Québec   Fall        45.0

# %%
b['Stem_count'].plot(kind='hist',color = "cornflowerblue", rwidth=0.95)
plt.title('Fall')
plt.xlabel('Stem count')
plt.ylabel('No. of obsevation')
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
#plt.axvspan(x, y, color='w', alpha=0.5, lw=0)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('season_fall_stem_count.jpg', dpi= 500)

# %%
k=df[df['Stem_count']<=150]
k['Stem_count'].plot(kind='hist',bins=100, color = "steelblue", rwidth=0.95)
#plt.title('Stem_count Histogram')
plt.xlabel('Stem count')
plt.ylabel('No. of obsevation')
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
#plt.axvspan(x, y, color='orange', alpha=0.5, lw=0)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('stem_count_histogram.jpg', dpi= 500)

# %%
data1 = k['Stem_count']

# %%
fd.Province.unique()
# Out:
# array(['Québec', nan, 'Ontario', 'Nouvelle-Écosse', 'Manitoba'],
#       dtype=object)

# %%
c=fd.loc[(fd['Province']== 'Manitoba')]
c.head()
# Out:
#       Province  Season  Stem_count
# 2384  Manitoba  Spring        45.0
# 2385  Manitoba  Spring        50.0
# 2386  Manitoba  Spring        30.0
# 2387  Manitoba  Spring        54.0
# 2388  Manitoba  Spring        45.0

# %%
c['Stem_count'].plot(kind='hist', bins= 50, color = "bisque", rwidth=0.95)
plt.title('Manitoba')
plt.xlabel('Stem count')
plt.ylabel('No. of obsevation')
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
#plt.axvspan(x, y, color='orange', alpha=0.5, lw=0)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('province_Manitoba_stem_count.jpg', dpi= 500)

# %%
data5 = c['Stem_count']

# %%
plt.figure(figsize=(8,6))
plt.hist(data1, bins=100, color = "steelblue", alpha=1.0, label="Total")
plt.hist(data5, bins=50, color = "bisque", alpha=1, label="Manitoba")
#plt.hist(data3, bins=100, alpha=0.5, label="Potassium (K)")
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
plt.xlabel("Stem count", size=14)
plt.ylabel("No. of obsevation", size=14)
#plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='best')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("Total_Manitoba_Overlapping_histogram.jpg", dpi= 500)

# %%
d=fd.loc[(fd['Province']== 'Ontario')]
d.head()
# Out:
#      Province Season  Stem_count
# 1286  Ontario   Fall        35.0
# 1287  Ontario   Fall        35.0
# 1288  Ontario   Fall        38.0
# 1290  Ontario   Fall        41.0
# 1291  Ontario   Fall        42.0

# %%
d['Stem_count'].plot(kind='hist', bins=30, color = "burlywood", rwidth=0.95)
plt.title('Ontario')
plt.xlabel('Stem count')
plt.ylabel('No. of obsevation')
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
#plt.axvspan(x, y, color='orange', alpha=0.5, lw=0)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('province_Ontario_stem_count.jpg', dpi= 500)

# %%
data4 = d['Stem_count']

# %%
plt.figure(figsize=(8,6))
plt.hist(data1, bins=100, color = "steelblue", alpha=1.0, label="Total")
plt.hist(data4, bins=30, color = "burlywood", alpha=1.0, label="Ontario")
#plt.hist(data3, bins=100, alpha=0.5, label="Potassium (K)")
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
plt.xlabel("Stem count", size=14)
plt.ylabel("No. of obsevation", size=14)
#plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='best')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("Total_Ontario_Overlapping_histogram.jpg", dpi= 500)

# %%
e=fd.loc[(fd['Province']== 'Nova Scotia')]
e.head()
# Out:
# Empty DataFrame
# Columns: [Province, Season, Stem_count]
# Index: []

# %%
e['Stem_count'].plot(kind='hist', bins=10, color = "aquamarine", rwidth=0.95)
plt.title('Nova Scotia')
plt.xlabel('Stem count')
plt.ylabel('No. of obsevation')
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
#plt.axvspan(x, y, color='orange', alpha=0.5, lw=0)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('province_Nova Scotia_stem_count.jpg', dpi= 500)

# %%
data3 = e['Stem_count']

# %%
plt.figure(figsize=(8,6))
plt.hist(data1, bins=100, color = "steelblue", alpha=1.0, label="Total")
plt.hist(data3, bins=10, color = "aquamarine", alpha=1.0, label="Nova Scotia")
#plt.hist(data3, bins=100, alpha=0.5, label="Potassium (K)")
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
plt.xlabel("Stem count", size=14)
plt.ylabel("No. of obsevation", size=14)
#plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='best')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("Total_Nova Scotia_Overlapping_histogram.jpg", dpi= 500)

# %%
f=(fd.loc[(fd['Province']== 'Quebec') | (fd['Province']== 'Québec')])
f.head()
# Out:
#   Province Season  Stem_count
# 0   Québec   Fall        17.0
# 1   Québec   Fall        10.0
# 2   Québec   Fall         5.0
# 3   Québec   Fall         4.0
# 4   Québec   Fall        45.0

# %%
f['Stem_count'].plot(kind='hist', bins= 100, color = "mediumaquamarine", rwidth=0.95)
plt.title('Quebec')
plt.xlabel('Stem count')
plt.ylabel('No. of obsevation')
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
#plt.axvspan(x, y, color='orange', alpha=0.5, lw=0)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('province_Quebec_stem_count.jpg', dpi= 500)

# %%
data2 = f['Stem_count']

# %%
plt.figure(figsize=(8,6))
plt.hist(data1, bins=100, color = "steelblue", alpha=1.0, label="Total")
plt.hist(data2, bins=100,color = "mediumaquamarine", alpha=1.0, label="Quebec")
#plt.hist(data3, bins=100, alpha=0.5, label="Potassium (K)")
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
plt.xlabel("Stem count", size=14)
plt.ylabel("No. of obsevation", size=14)
#plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='best')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("Total_Quebec_Overlapping_histogram.jpg", dpi= 500)

# %%
plt.figure(figsize=(8,6))

plt.hist(data2, bins=100,color = "mediumaquamarine", alpha=1, label="Quebec")
plt.hist(data5, bins=50, color = "bisque", alpha=1, label="Manitoba")
plt.hist(data4, bins=30, color = "burlywood", alpha=1, label="Ontario")
plt.hist(data3, bins=10, color = "aquamarine", alpha=1, label="Nova Scotia")


#plt.hist(data3, bins=100, alpha=0.5, label="Potassium (K)")
x = 10
y = 90
plt.axvline(x, color='k', linestyle='dashed', linewidth=1)
plt.axvline(y, color='k', linestyle='dashed', linewidth=1)
plt.xlabel("Stem count", size=14)
plt.ylabel("No. of obsevation", size=14)
#plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='best')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("Combined_province_Overlapping_histogram.jpg", dpi= 500)
