# %%
import pandas as pd

# %% [markdown]
# # Province add in unique id

# %%
id_unique = pd.read_excel(r'C:\Users\Shahadat Shuchon\Documents\M.Saif\Data Model\Data_model_100222.xlsx', sheet_name= 'ID_unique')
id_unique.head(2)
# Out:
#    Society_no                             Society_name Field_name  Field_no  \
# 0       37034                              Hurni, Andr          3  84356113
# 1       37034  Hurni, AndrLas (Ferme Techno-Lait SENC)         33  84356112
#
#                               Unique_ID CULTURE                  User  \
# 0  3c88a96e-45cd-41a9-979f-c739f8b9e054     NaN  Elizabeth  L'Heureux
# 1  71378500-5572-449c-a541-fcd4dfba90e1     NaN  Elizabeth  L'Heureux
#
#                    Farm_name       Producer              Adviser  JIRA_ID  \
# 0  Ferme Techno-Lait S.EN.C.  Andréas Hurni  Elisabeth L'Heureux        0
# 1  Ferme Techno-Lait S.EN.C.  Andréas Hurni  Elisabeth L'Heureux        0
#
#    Longitude   Latitude
# 0 -72.612200  45.747451
# 1 -72.597395  45.763746

# %%
crop_history = pd.read_excel(r'C:\Users\Shahadat Shuchon\Documents\M.Saif\Data Model\Data_model_100222.xlsx', sheet_name= 'Crop_history')
crop_history.head(2)
# Out:
#    Field_no  Society_no                         Society_name Field_name  \
# 0  84912419       37045  Saint-Pierre, Yvan (Ferme Dupierre)         16
# 1  84912419       37045  Saint-Pierre, Yvan (Ferme Dupierre)         16
#
#                               Unique_ID               Culture  JIRA_ID  \
# 0  66aaeb9d-ecc2-4eff-9847-1f7c9d025aaf  Foin de légumineuses        0
# 1  66aaeb9d-ecc2-4eff-9847-1f7c9d025aaf  Foin de légumineuses        0
#
#         Farm_Name        Producer    Adviser Province    Year  \
# 0  Ferme Dupierre  Yvan St-PIerre  Lise Dube   Quebec  2015.0
# 1  Ferme Dupierre  Yvan St-PIerre  Lise Dube   Quebec  2016.0
#
#    Culture_English  Annual Vs perenial  C4/C3  Grass/legum/brassicas/cereal  \
# 0              NaN                 NaN    NaN                           NaN
# 1              NaN                 NaN    NaN                           NaN
#
#    Forage/cash crop  Stand age
# 0               NaN        NaN
# 1               NaN        NaN

# %%
crop_history = crop_history[['Unique_ID','Province']]
crop_history.head(2)
# Out:
#                               Unique_ID Province
# 0  66aaeb9d-ecc2-4eff-9847-1f7c9d025aaf   Quebec
# 1  66aaeb9d-ecc2-4eff-9847-1f7c9d025aaf   Quebec

# %%
id_unique_rev = id_unique.set_index('Unique_ID').join(crop_history.set_index('Unique_ID'))
id_unique_rev=id_unique_rev.reset_index()
id_unique_rev=id_unique_rev.drop_duplicates(subset='Unique_ID',keep='first')
id_unique_rev.head(2)
# Out:
#                               Unique_ID  Society_no  \
# 0  0057ebbe-719e-45ad-b6b7-1301f2fafd93       36911
# 1  00eebf83-f180-41d2-a8e2-db4b7379df69       37219
#
#                                Society_name Field_name  Field_no  \
# 0  Goulet, Pierre (Ferme Martin Goulet inc)         03  92087603
# 1      Mtthot, Alexandre (Denis Methot inc)          5  91366628
#
#                          CULTURE             User  \
# 0  Foin de l7gumineuses 3 coupes  Dominique Fiset
# 1                            NaN      Automatique
#
#                                     Farm_name          Producer  \
# 0  "Goulet, Pierre (Ferme Martin Goulet inc)"     Pierre Goulet
# 1        Méthot, Alexandre (Denis Méthot inc)  Alexandre Méthot
#
#              Adviser  JIRA_ID  Longitude   Latitude Province
# 0    Dominique Fiset      273 -71.129825  46.474471      NaN
# 1  Catherine Mercier      177 -72.928331  45.942638      NaN

# %% [markdown]
# # stem count raw and id unique_rev join

# %%
stem_raw = pd.read_excel(r'C:\Users\Shahadat Shuchon\Documents\M.Saif\Data Model\Data_model_100222.xlsx', sheet_name ='Stem_count_raw')
stem_raw.head(2)
# Out:
#    Column1  JIRA_ID         Farm_name      Producer               Road  \
# 0        1      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1        2      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province Postal_code  Year  \
# 0      Mirabel   Québec      J7N2R8  2021
# 1      Mirabel   Québec      J7N2R8  2021
#
#                               Unique_ID  ...  Height_1cm Height_2cm  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        17.0       20.0
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...        20.0       20.0
#
#    Height_3cm Height_4cm Height_5cm Évaluation des racines  Longitude  \
# 0        22.0       24.0       27.0                    NaN -74.091891
# 1        26.0       22.0       22.0                    NaN -74.091917
#
#     Latitude  Land_mark                                 Photo
# 0  45.547272        1.0  81a02657-8444-4e49-937d-6d944ee2387a
# 1  45.547241        3.0  d2daa5e0-286f-4d0e-84c5-c916d028312e
#
# [2 rows x 27 columns]

# %%
stem_id_unique = pd.merge(stem_raw, id_unique_rev, on="Unique_ID", how='left')
stem_id_unique.head(2)
# Out:
#    Column1  JIRA_ID_x       Farm_name_x    Producer_x               Road  \
# 0        1        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1        2        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province_x Postal_code  Year  \
# 0      Mirabel     Québec      J7N2R8  2021
# 1      Mirabel     Québec      J7N2R8  2021
#
#                               Unique_ID  ...    Field_no             CULTURE  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...  92247457.0  Foin 1tablissement
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...  92247457.0  Foin 1tablissement
#
#      User                                   Farm_name_y     Producer_y  \
# 0  Logiag  "Luzerne - Leduc, Pascal (Ferme Pioui SENC)"  Leduc, Pascal
# 1  Logiag  "Luzerne - Leduc, Pascal (Ferme Pioui SENC)"  Leduc, Pascal
#
#       Adviser  JIRA_ID_y  Longitude_y  Latitude_y  Province_y
# 0  Evens Jean      136.0   -74.091179   45.546638           0
# 1  Evens Jean      136.0   -74.091179   45.546638           0
#
# [2 rows x 40 columns]

# %% [markdown]
# # Month Extraction

# %%
stem_id_unique['Month'] = stem_id_unique['Date'].dt.month
stem_id_unique['Month'] = stem_id_unique['Date'].dt.strftime('%B')
stem_id_unique.head(2)
# Out:
#    Column1  JIRA_ID_x       Farm_name_x    Producer_x               Road  \
# 0        1        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1        2        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province_x Postal_code  Year  \
# 0      Mirabel     Québec      J7N2R8  2021
# 1      Mirabel     Québec      J7N2R8  2021
#
#                               Unique_ID  ...             CULTURE    User  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...  Foin 1tablissement  Logiag
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...  Foin 1tablissement  Logiag
#
#                                     Farm_name_y     Producer_y     Adviser  \
# 0  "Luzerne - Leduc, Pascal (Ferme Pioui SENC)"  Leduc, Pascal  Evens Jean
# 1  "Luzerne - Leduc, Pascal (Ferme Pioui SENC)"  Leduc, Pascal  Evens Jean
#
#   JIRA_ID_y  Longitude_y  Latitude_y  Province_y      Month
# 0     136.0   -74.091179   45.546638           0  September
# 1     136.0   -74.091179   45.546638           0  September
#
# [2 rows x 41 columns]

# %% [markdown]
# # season inclution

# %%
def label_race (row):
   if row['Month'] == 'May' :
      return 'Spring'
   if row['Month'] == 'June' :
      return 'Spring'
   if row['Month'] == 'July' :
      return 'Spring'
   if row['Month'] == 'August':
      return 'Fall'
   if row['Month']  == 'September':
      return 'Fall'
   if row['Month'] == 'October':
      return 'Fall'
   if row['Month'] == 'November':
      return 'Fall'
   if row['Month'] == 'December':
      return 'Fall'

# %%
stem_id_unique['Season'] = stem_id_unique.apply (lambda row: label_race(row), axis=1)
stem_id_unique.head(2)
# Out:
#    Column1  JIRA_ID_x       Farm_name_x    Producer_x               Road  \
# 0        1        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
# 1        2        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere
#
#   Municipality Province_x Postal_code  Year  \
# 0      Mirabel     Québec      J7N2R8  2021
# 1      Mirabel     Québec      J7N2R8  2021
#
#                               Unique_ID  ...    User  \
# 0  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...  Logiag
# 1  b24c817a-a143-4520-b1b6-9d430f6cf33e  ...  Logiag
#
#                                     Farm_name_y     Producer_y     Adviser  \
# 0  "Luzerne - Leduc, Pascal (Ferme Pioui SENC)"  Leduc, Pascal  Evens Jean
# 1  "Luzerne - Leduc, Pascal (Ferme Pioui SENC)"  Leduc, Pascal  Evens Jean
#
#   JIRA_ID_y Longitude_y  Latitude_y  Province_y      Month  Season
# 0     136.0  -74.091179   45.546638           0  September    Fall
# 1     136.0  -74.091179   45.546638           0  September    Fall
#
# [2 rows x 42 columns]

# %% [markdown]
# # Dataframe  refurbish

# %%
stem_id_unique=stem_id_unique.drop(['Column1', 'Field_name_y','Farm_name_y','Producer_y','JIRA_ID_y','Longitude_y','Latitude_y','Province_y' ], axis=1)
stem_id_unique.head(2)
# Out:
#    JIRA_ID_x       Farm_name_x    Producer_x               Road Municipality  \
# 0        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere      Mirabel
# 1        136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere      Mirabel
#
#   Province_x Postal_code  Year                             Unique_ID  \
# 0     Québec      J7N2R8  2021  b24c817a-a143-4520-b1b6-9d430f6cf33e
# 1     Québec      J7N2R8  2021  b24c817a-a143-4520-b1b6-9d430f6cf33e
#
#    Field_number  ... Land_mark                                 Photo  \
# 0        5604.0  ...       1.0  81a02657-8444-4e49-937d-6d944ee2387a
# 1        5604.0  ...       3.0  d2daa5e0-286f-4d0e-84c5-c916d028312e
#
#   Society_no                                Society_name    Field_no  \
# 0    36832.0  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0
# 1    36832.0  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0
#
#               CULTURE    User     Adviser      Month  Season
# 0  Foin 1tablissement  Logiag  Evens Jean  September    Fall
# 1  Foin 1tablissement  Logiag  Evens Jean  September    Fall
#
# [2 rows x 34 columns]

# %%
stem_id_unique.columns
# Out:
# Index(['JIRA_ID_x', 'Farm_name_x', 'Producer_x', 'Road', 'Municipality',
#        'Province_x', 'Postal_code', 'Year', 'Unique_ID', 'Field_number',
#        'Field_name_x', 'Point_no', 'Point_name', 'Status', 'Date',
#        'Stem_count', 'Height_1cm', 'Height_2cm', 'Height_3cm', 'Height_4cm',
#        'Height_5cm', 'Évaluation des racines', 'Longitude_x', 'Latitude_x',
#        'Land_mark', 'Photo', 'Society_no', 'Society_name', 'Field_no',
#        'CULTURE', 'User', 'Adviser', 'Month', 'Season'],
#       dtype='object')

# %%
stem_id_unique= stem_id_unique.rename({'JIRA_ID_x':'JIRA_ID', 'Farm_name_x':'Farm_Name', 'Producer_x':'Producer', 'Province_x':'Province', 'Field_name_x':'Field_name', 'Longitude_x':'Longitude', 'Latitude_x':'Latitude'}, axis='columns')
stem_id_unique.head(2)
# Out:
#    JIRA_ID         Farm_Name      Producer               Road Municipality  \
# 0      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere      Mirabel
# 1      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere      Mirabel
#
#   Province Postal_code  Year                             Unique_ID  \
# 0   Québec      J7N2R8  2021  b24c817a-a143-4520-b1b6-9d430f6cf33e
# 1   Québec      J7N2R8  2021  b24c817a-a143-4520-b1b6-9d430f6cf33e
#
#    Field_number  ... Land_mark                                 Photo  \
# 0        5604.0  ...       1.0  81a02657-8444-4e49-937d-6d944ee2387a
# 1        5604.0  ...       3.0  d2daa5e0-286f-4d0e-84c5-c916d028312e
#
#   Society_no                                Society_name    Field_no  \
# 0    36832.0  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0
# 1    36832.0  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0
#
#               CULTURE    User     Adviser      Month  Season
# 0  Foin 1tablissement  Logiag  Evens Jean  September    Fall
# 1  Foin 1tablissement  Logiag  Evens Jean  September    Fall
#
# [2 rows x 34 columns]

# %% [markdown]
# # Filtering nan rows

# %%
stem_id_unique = stem_id_unique[stem_id_unique[['Point_no', 'Stem_count', 'Height_1cm','Height_2cm','Height_3cm','Height_4cm','Height_5cm','Longitude','Latitude']].notnull().all(1)]
stem_id_unique.head(2)
# Out:
#    JIRA_ID         Farm_Name      Producer               Road Municipality  \
# 0      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere      Mirabel
# 1      136  Ferme Pioui SENC  Pascal Leduc  8821 rg Fresniere      Mirabel
#
#   Province Postal_code  Year                             Unique_ID  \
# 0   Québec      J7N2R8  2021  b24c817a-a143-4520-b1b6-9d430f6cf33e
# 1   Québec      J7N2R8  2021  b24c817a-a143-4520-b1b6-9d430f6cf33e
#
#    Field_number  ... Land_mark                                 Photo  \
# 0        5604.0  ...       1.0  81a02657-8444-4e49-937d-6d944ee2387a
# 1        5604.0  ...       3.0  d2daa5e0-286f-4d0e-84c5-c916d028312e
#
#   Society_no                                Society_name    Field_no  \
# 0    36832.0  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0
# 1    36832.0  Luzerne - Leduc, Pascal (Ferme Pioui SENC)  92247457.0
#
#               CULTURE    User     Adviser      Month  Season
# 0  Foin 1tablissement  Logiag  Evens Jean  September    Fall
# 1  Foin 1tablissement  Logiag  Evens Jean  September    Fall
#
# [2 rows x 34 columns]

# %%
stem_id_unique.to_excel("stem_id_unique.xlsx")

# %%
stem_id_unique.Province.unique()
# Out:
# array(['Québec', nan, 'Ontario', 'Nouvelle-Écosse', 'Manitoba'],
#       dtype=object)
